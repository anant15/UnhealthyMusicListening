# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Data_HUMS_Traits.csv")

data.columns = list(map(lambda it: it.strip("'"), data.columns))

data = data.drop(["BMRQ.Social_Reward", 
           "BMRQ.Musical_Seeking", 
           "BMRQ.Mood_Regulation", 
           "BMRQ.Sensory_Motor", 
           "BMRQ.Emotional_Evocation",
                 "HUMS.Healthy"], axis=1)

# %%
X = data.drop('HUMS.Unhealthy', axis=1)
y = data['HUMS.Unhealthy']

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(2, interaction_only=True, include_bias=False)

x_interaction = poly.fit_transform(X)
x_interaction_columns = poly.get_feature_names(input_features=X.columns)
interaction_df = pd.DataFrame(x_interaction, columns=x_interaction_columns)

# %%
from statsmodels.regression import linear_model

model = linear_model.OLS(y, X).fit()
interaction_model = linear_model.OLS(y, interaction_df).fit()

# %%
model.pvalues[model.pvalues < 0.05]
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:         HUMS.Unhealthy   R-squared (uncentered):                   0.935
# Model:                            OLS   Adj. R-squared (uncentered):              0.932
# Method:                 Least Squares   F-statistic:                              311.0
# Date:                Mon, 12 Oct 2020   Prob (F-statistic):                   9.01e-171
# Time:                        13:42:12   Log-Likelihood:                         -928.93
# No. Observations:                 318   AIC:                                      1886.
# Df Residuals:                     304   BIC:                                      1939.
# Df Model:                          14
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# IRI.Perspective_Taking     0.6036      0.081      7.491      0.000       0.445       0.762
# IRI.Fantasy                0.0019      0.063      0.030      0.976      -0.121       0.125
# IRI.Empathic_Concern      -0.4525      0.085     -5.322      0.000      -0.620      -0.285
# IRI.Personal_Distress      0.3489      0.075      4.669      0.000       0.202       0.496
# EC.Happiness              -0.4114      0.201     -2.045      0.042      -0.807      -0.016
# EC.Love                    0.3399      0.140      2.423      0.016       0.064       0.616
# EC.Fear                    0.1038      0.192      0.539      0.590      -0.275       0.482
# EC.Anger                  -0.0220      0.188     -0.117      0.907      -0.393       0.349
# EC.Sadness                 0.3646      0.174      2.090      0.037       0.021       0.708
# P.Extraversion             0.1814      0.045      4.014      0.000       0.092       0.270
# P.Agreeableness           -0.1409      0.064     -2.199      0.029      -0.267      -0.015
# P.Conscientiousness        0.0163      0.045      0.361      0.718      -0.073       0.105
# P.Neuroticism              0.0947      0.052      1.813      0.071      -0.008       0.197
# P.Openness                 0.0543      0.051      1.058      0.291      -0.047       0.155
# ==============================================================================
# Omnibus:                       16.627   Durbin-Watson:                   2.056
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.732
# Skew:                           0.546   Prob(JB):                     0.000141
# Kurtosis:                       3.380   Cond. No.                         76.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
interaction_model.pvalues[interaction_model.pvalues < 0.05]
# Out:
# IRI.Fantasy                                    0.039551
# IRI.Empathic_Concern                           0.015446
# IRI.Personal_Distress                          0.013680
# EC.Happiness                                   0.006530
# EC.Sadness                                     0.027415
# IRI.Perspective_Taking IRI.Empathic_Concern    0.014706
# IRI.Perspective_Taking EC.Fear                 0.000405
# IRI.Empathic_Concern IRI.Personal_Distress     0.011849
# IRI.Empathic_Concern EC.Happiness              0.013836
# EC.Love EC.Sadness                             0.008272
# EC.Fear P.Extraversion                         0.003302
# EC.Fear P.Agreeableness                        0.007468
# EC.Fear P.Openness                             0.016793
# EC.Sadness P.Extraversion                      0.038067
# EC.Sadness P.Conscientiousness                 0.035973
# dtype: float64

# %%
interaction_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:         HUMS.Unhealthy   R-squared (uncentered):                   0.963
# Model:                            OLS   Adj. R-squared (uncentered):              0.945
# Method:                 Least Squares   F-statistic:                              53.26
# Date:                Mon, 12 Oct 2020   Prob (F-statistic):                   2.78e-112
# Time:                        13:32:15   Log-Likelihood:                         -837.35
# No. Observations:                 318   AIC:                                      1885.
# Df Residuals:                     213   BIC:                                      2280.
# Df Model:                         105
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# IRI.Perspective_Taking                          -0.5842      1.017     -0.575      0.566      -2.588       1.420
# IRI.Fantasy                                      1.8543      0.895      2.071      0.040       0.090       3.619
# IRI.Empathic_Concern                             2.9670      1.215      2.441      0.015       0.571       5.363
# IRI.Personal_Distress                           -2.3917      0.962     -2.486      0.014      -4.288      -0.495
# EC.Happiness                                    -8.0411      2.927     -2.747      0.007     -13.811      -2.271
# EC.Love                                          2.2981      2.461      0.934      0.352      -2.554       7.150
# EC.Fear                                          4.8220      3.042      1.585      0.114      -1.174      10.818
# EC.Anger                                         1.0838      2.750      0.394      0.694      -4.338       6.505
# EC.Sadness                                      -5.7476      2.588     -2.221      0.027     -10.849      -0.646
# P.Extraversion                                   0.2615      0.551      0.475      0.635      -0.824       1.347
# P.Agreeableness                                  0.5345      0.924      0.579      0.563      -1.287       2.356
# P.Conscientiousness                              0.0033      0.529      0.006      0.995      -1.038       1.045
# P.Neuroticism                                    1.0872      0.592      1.837      0.068      -0.079       2.254
# P.Openness                                      -1.1474      0.624     -1.838      0.067      -2.378       0.083
# IRI.Perspective_Taking IRI.Fantasy              -0.0017      0.025     -0.069      0.945      -0.050       0.047
# IRI.Perspective_Taking IRI.Empathic_Concern     -0.0795      0.032     -2.460      0.015      -0.143      -0.016
# IRI.Perspective_Taking IRI.Personal_Distress     0.0345      0.025      1.360      0.175      -0.015       0.084
# IRI.Perspective_Taking EC.Happiness             -0.1210      0.074     -1.644      0.102      -0.266       0.024
# IRI.Perspective_Taking EC.Love                  -0.0744      0.049     -1.506      0.134      -0.172       0.023
# IRI.Perspective_Taking EC.Fear                   0.2168      0.060      3.594      0.000       0.098       0.336
# IRI.Perspective_Taking EC.Anger                 -0.0509      0.063     -0.809      0.420      -0.175       0.073
# IRI.Perspective_Taking EC.Sadness               -0.0215      0.059     -0.364      0.717      -0.138       0.095
# IRI.Perspective_Taking P.Extraversion            0.0076      0.019      0.407      0.684      -0.029       0.044
# IRI.Perspective_Taking P.Agreeableness           0.0185      0.022      0.830      0.407      -0.025       0.062
# IRI.Perspective_Taking P.Conscientiousness       0.0203      0.018      1.119      0.264      -0.015       0.056
# IRI.Perspective_Taking P.Neuroticism             0.0193      0.019      1.016      0.311      -0.018       0.057
# IRI.Perspective_Taking P.Openness                0.0351      0.018      1.904      0.058      -0.001       0.072
# IRI.Fantasy IRI.Empathic_Concern                 0.0145      0.023      0.629      0.530      -0.031       0.060
# IRI.Fantasy IRI.Personal_Distress               -0.0215      0.022     -0.968      0.334      -0.065       0.022
# IRI.Fantasy EC.Happiness                         0.0472      0.059      0.805      0.422      -0.068       0.163
# IRI.Fantasy EC.Love                             -0.0586      0.040     -1.484      0.139      -0.137       0.019
# IRI.Fantasy EC.Fear                             -0.0949      0.053     -1.786      0.076      -0.200       0.010
# IRI.Fantasy EC.Anger                            -0.0278      0.048     -0.581      0.562      -0.122       0.066
# IRI.Fantasy EC.Sadness                           0.0605      0.044      1.366      0.173      -0.027       0.148
# IRI.Fantasy P.Extraversion                      -0.0092      0.013     -0.728      0.467      -0.034       0.016
# IRI.Fantasy P.Agreeableness                      0.0007      0.020      0.035      0.972      -0.038       0.039
# IRI.Fantasy P.Conscientiousness                 -0.0043      0.013     -0.333      0.740      -0.030       0.021
# IRI.Fantasy P.Neuroticism                       -0.0080      0.017     -0.480      0.632      -0.041       0.025
# IRI.Fantasy P.Openness                          -0.0172      0.014     -1.214      0.226      -0.045       0.011
# IRI.Empathic_Concern IRI.Personal_Distress      -0.0745      0.029     -2.538      0.012      -0.132      -0.017
# IRI.Empathic_Concern EC.Happiness                0.1961      0.079      2.482      0.014       0.040       0.352
# IRI.Empathic_Concern EC.Love                    -0.0625      0.053     -1.189      0.236      -0.166       0.041
# IRI.Empathic_Concern EC.Fear                     0.0344      0.083      0.416      0.678      -0.129       0.197
# IRI.Empathic_Concern EC.Anger                   -0.1100      0.071     -1.554      0.122      -0.250       0.030
# IRI.Empathic_Concern EC.Sadness                  0.0142      0.071      0.198      0.843      -0.127       0.155
# IRI.Empathic_Concern P.Extraversion             -0.0245      0.020     -1.238      0.217      -0.064       0.015
# IRI.Empathic_Concern P.Agreeableness             0.0201      0.019      1.034      0.302      -0.018       0.059
# IRI.Empathic_Concern P.Conscientiousness        -0.0365      0.020     -1.836      0.068      -0.076       0.003
# IRI.Empathic_Concern P.Neuroticism              -0.0087      0.021     -0.415      0.679      -0.050       0.033
# IRI.Empathic_Concern P.Openness                  0.0012      0.020      0.057      0.955      -0.039       0.041
# IRI.Personal_Distress EC.Happiness               0.0020      0.070      0.028      0.977      -0.137       0.141
# IRI.Personal_Distress EC.Love                    0.0213      0.053      0.405      0.686      -0.083       0.125
# IRI.Personal_Distress EC.Fear                    0.0087      0.062      0.141      0.888      -0.114       0.131
# IRI.Personal_Distress EC.Anger                   0.0942      0.062      1.524      0.129      -0.028       0.216
# IRI.Personal_Distress EC.Sadness                 0.0767      0.054      1.414      0.159      -0.030       0.184
# IRI.Personal_Distress P.Extraversion             0.0212      0.015      1.417      0.158      -0.008       0.051
# IRI.Personal_Distress P.Agreeableness            0.0109      0.021      0.530      0.597      -0.030       0.052
# IRI.Personal_Distress P.Conscientiousness        0.0228      0.016      1.404      0.162      -0.009       0.055
# IRI.Personal_Distress P.Neuroticism              0.0084      0.014      0.599      0.549      -0.019       0.036
# IRI.Personal_Distress P.Openness                 0.0225      0.017      1.308      0.192      -0.011       0.056
# EC.Happiness EC.Love                            -0.1804      0.111     -1.622      0.106      -0.400       0.039
# EC.Happiness EC.Fear                            -0.0792      0.156     -0.506      0.613      -0.387       0.229
# EC.Happiness EC.Anger                           -0.0413      0.164     -0.252      0.801      -0.365       0.282
# EC.Happiness EC.Sadness                          0.2010      0.156      1.292      0.198      -0.106       0.508
# EC.Happiness P.Extraversion                     -0.0333      0.038     -0.877      0.382      -0.108       0.042
# EC.Happiness P.Agreeableness                     0.0104      0.050      0.210      0.834      -0.088       0.109
# EC.Happiness P.Conscientiousness                 0.0618      0.048      1.293      0.197      -0.032       0.156
# EC.Happiness P.Neuroticism                       0.0412      0.053      0.783      0.435      -0.063       0.145
# EC.Happiness P.Openness                          0.0739      0.052      1.418      0.158      -0.029       0.177
# EC.Love EC.Fear                                 -0.0940      0.127     -0.741      0.460      -0.344       0.156
# EC.Love EC.Anger                                 0.0909      0.107      0.848      0.397      -0.120       0.302
# EC.Love EC.Sadness                               0.2704      0.101      2.666      0.008       0.070       0.470
# EC.Love P.Extraversion                           0.0111      0.026      0.419      0.676      -0.041       0.063
# EC.Love P.Agreeableness                          0.0141      0.040      0.356      0.722      -0.064       0.092
# EC.Love P.Conscientiousness                      0.0228      0.038      0.605      0.546      -0.051       0.097
# EC.Love P.Neuroticism                           -0.0017      0.042     -0.041      0.967      -0.085       0.081
# EC.Love P.Openness                               0.0234      0.033      0.711      0.478      -0.042       0.088
# EC.Fear EC.Anger                                 0.1627      0.122      1.329      0.185      -0.079       0.404
# EC.Fear EC.Sadness                              -0.0993      0.154     -0.646      0.519      -0.402       0.204
# EC.Fear P.Extraversion                           0.1118      0.038      2.972      0.003       0.038       0.186
# EC.Fear P.Agreeableness                         -0.1439      0.053     -2.701      0.007      -0.249      -0.039
# EC.Fear P.Conscientiousness                     -0.0441      0.047     -0.941      0.348      -0.136       0.048
# EC.Fear P.Neuroticism                            0.0109      0.049      0.224      0.823      -0.085       0.107
# EC.Fear P.Openness                              -0.1112      0.046     -2.410      0.017      -0.202      -0.020
# EC.Anger EC.Sadness                              0.0020      0.139      0.014      0.989      -0.272       0.276
# EC.Anger P.Extraversion                         -0.0372      0.039     -0.959      0.339      -0.114       0.039
# EC.Anger P.Agreeableness                         0.0652      0.051      1.283      0.201      -0.035       0.165
# EC.Anger P.Conscientiousness                    -0.0739      0.042     -1.757      0.080      -0.157       0.009
# EC.Anger P.Neuroticism                          -0.0485      0.048     -1.005      0.316      -0.144       0.047
# EC.Anger P.Openness                              0.0547      0.044      1.246      0.214      -0.032       0.141
# EC.Sadness P.Extraversion                       -0.0825      0.040     -2.087      0.038      -0.160      -0.005
# EC.Sadness P.Agreeableness                      -0.0329      0.052     -0.632      0.528      -0.135       0.070
# EC.Sadness P.Conscientiousness                   0.0897      0.043      2.111      0.036       0.006       0.173
# EC.Sadness P.Neuroticism                        -0.0526      0.043     -1.225      0.222      -0.137       0.032
# EC.Sadness P.Openness                            0.0265      0.045      0.593      0.554      -0.062       0.115
# P.Extraversion P.Agreeableness                  -0.0013      0.014     -0.095      0.924      -0.028       0.026
# P.Extraversion P.Conscientiousness               0.0082      0.011      0.754      0.452      -0.013       0.030
# P.Extraversion P.Neuroticism                    -0.0131      0.011     -1.231      0.220      -0.034       0.008
# P.Extraversion P.Openness                        0.0154      0.012      1.274      0.204      -0.008       0.039
# P.Agreeableness P.Conscientiousness             -0.0161      0.013     -1.255      0.211      -0.041       0.009
# P.Agreeableness P.Neuroticism                    0.0105      0.015      0.720      0.472      -0.018       0.039
# P.Agreeableness P.Openness                      -0.0242      0.017     -1.460      0.146      -0.057       0.008
# P.Conscientiousness P.Neuroticism               -0.0167      0.011     -1.455      0.147      -0.039       0.006
# P.Conscientiousness P.Openness                   0.0082      0.011      0.746      0.456      -0.013       0.030
# P.Neuroticism P.Openness                        -0.0063      0.012     -0.518      0.605      -0.030       0.018
# ==============================================================================
# Omnibus:                        3.783   Durbin-Watson:                   2.056
# Prob(Omnibus):                  0.151   Jarque-Bera (JB):                3.477
# Skew:                           0.226   Prob(JB):                        0.176
# Kurtosis:                       3.242   Cond. No.                     8.12e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.12e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
