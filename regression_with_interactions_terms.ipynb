# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Data_HUMS_Traits.csv")

data.columns = list(map(lambda it: it.strip("'"), data.columns))

data = data.drop(["BMRQ.Social_Reward", 
           "BMRQ.Musical_Seeking", 
           "BMRQ.Mood_Regulation", 
           "BMRQ.Sensory_Motor", 
           "BMRQ.Emotional_Evocation",
            "HUMS.Healthy"], axis=1)

# %%
X = data[["IRI.Personal_Distress", "EC.Fear", "EC.Sadness", "P.Neuroticism"]]
y = data["HUMS.Unhealthy"]

poly = PolynomialFeatures(2, interaction_only=True, include_bias=False)
scaler = MinMaxScaler()

X_interaction_neg_emotions = poly.fit_transform(X)
X_interaction_neg_emotions_columns = poly.get_feature_names(input_features=X.columns)
interaction_df_neg_emotions = pd.DataFrame(X_interaction, columns=X_interaction_neg_emotions_columns)
interaction_df_neg_emotions_norm = pd.DataFrame(scaler.fit_transform(interaction_df_neg_emotions), columns=interaction_df_neg_emotions.columns)
interaction_df_neg_emotions_norm = sm.add_constant(interaction_df_neg_emotions_norm)

neg_emotions_model = linear_model.OLS(y, interaction_df_neg_emotions_norm).fit()

# %%
print(neg_emotions_model.params[neg_emotions_model.pvalues < 0.05].sort_values())
neg_emotions_model.summary()
# Out:
# const                               10.957411
# P.Neuroticism                       32.793670
# IRI.Personal_Distress EC.Sadness    46.196016
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         HUMS.Unhealthy   R-squared:                       0.168
# Model:                            OLS   Adj. R-squared:                  0.141
# Method:                 Least Squares   F-statistic:                     6.216
# Date:                Mon, 12 Oct 2020   Prob (F-statistic):           1.16e-08
# Time:                        19:49:23   Log-Likelihood:                -971.16
# No. Observations:                 318   AIC:                             1964.
# Df Residuals:                     307   BIC:                             2006.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...

# %%
X = data[["IRI.Personal_Distress", "EC.Fear", "EC.Sadness", "P.Neuroticism", "P.Openness", "P.Extraversion"]]
y = data["HUMS.Unhealthy"]

poly = PolynomialFeatures(2, interaction_only=True, include_bias=False)
X_interaction_neg_emotions = poly.fit_transform(X)
X_interaction_neg_emotions_columns = poly.get_feature_names(input_features=X.columns)
interaction_df_neg_emotions = pd.DataFrame(X_interaction_neg_emotions, columns=X_interaction_neg_emotions_columns)
interaction_df_neg_emotions_norm = pd.DataFrame(scaler.fit_transform(interaction_df_neg_emotions), columns=interaction_df_neg_emotions.columns)
interaction_df_neg_emotions_norm = sm.add_constant(interaction_df_neg_emotions_norm)

neg_emotions_model = linear_model.OLS(y, interaction_df_neg_emotions_norm).fit()

print(neg_emotions_model.params[neg_emotions_model.pvalues < 0.05].sort_values())
neg_emotions_model.summary()
# Out:
# P.Neuroticism                       47.334340
# IRI.Personal_Distress EC.Sadness    50.954565
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         HUMS.Unhealthy   R-squared:                       0.226
# Model:                            OLS   Adj. R-squared:                  0.171
# Method:                 Least Squares   F-statistic:                     4.110
# Date:                Mon, 12 Oct 2020   Prob (F-statistic):           1.68e-08
# Time:                        19:50:43   Log-Likelihood:                -959.80
# No. Observations:                 318   AIC:                             1964.
# Df Residuals:                     296   BIC:                             2046.
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# ...
